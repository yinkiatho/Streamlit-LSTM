# %%
from __future__ import division
import pandas as pd
import numpy as np
import datetime
import time
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Conv1D, Flatten, MaxPooling1D, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler

data = pd.read_csv("Datasets/SPY_30years.csv",
                   index_col="Date", parse_dates=True)

# %%
data.info()
# data.drop(['Dividends', 'Stock Splits', "Capital Gains"], axis=1, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7263 entries, 1994-01-27 to 2022-11-30
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Open               7263 non-null   float64
#  1   High               7263 non-null   float64
#  2   Low                7263 non-null   float64
#  3   Close              7263 non-null   float64
#  4   Adj Close          7263 non-null   float64
#  5   Volume             7263 non-null   int64
#  6   SMA_5              7263 non-null   float64
#  7   SMA_20             7263 non-null   float64
#  8   SMA_50             7263 non-null   float64
#  9   SMA_252            7263 non-null   float64
#  10  daily_return       7263 non-null   float64
#  11  monthly_return     7263 non-null   float64
#  12  adv20              7263 non-null   float64
#  13  VWAP               7263 non-null   float64
#  14  log_returns        7263 non-null   float64
#  15  volatility_30      7263 non-null   float64
#  16  volatility_60      7263 non-null   float64
#  17  annual_volatility  7263 non-null   float64
#  18  rapp               7263 non-null   float64
# dtypes: float64(18), int64(1)
# memory usage: 1.1 MB

# %%
row = pd.DataFrame(df.iloc[-1, :]).transpose()
(row['SMA_5'] > row['SMA_20']).index
# Out:
# DatetimeIndex(['2023-01-03'], dtype='datetime64[ns]', freq=None)

# %%
df = data['Close']
#print(df.values)
dataset = df.values.reshape(-1, 1)
training_data_len = int(np.ceil(len(dataset) * .95))

training_data_len

dataset.shape
# Out:
# (7263, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# %%
train, test = scaled_data[0:int(
    len(dataset) * 0.7), :], scaled_data[int(len(dataset) * 0.7): , :]

# %%
def reconstruct_data(data, n=1):
    data = pd.DataFrame(data)
    x, y = [], []
    for i in range(len(data) - n - 1):
        x.append(data.iloc[i:(i + n), :])
        # append close price
        y.append(data.iloc[i + n, 0])

    return (np.array(x), np.array(y))


train_x, train_y = reconstruct_data(train, 5)
test_x, test_y = reconstruct_data(test, 5)
print(train_x.shape, train_y.shape)
# Out:
# (5078, 5, 1) (5078,)

# %%
from keras import callbacks
n_splits = 5
tscv = TimeSeriesSplit(n_splits=n_splits)


def model_lstm(window, features):

    # current best
    model4 = Sequential()
    model4.add(LSTM(300, input_shape=(window, features), return_sequences=True))
    model4.add(Dropout(0.5))
    model4.add(LSTM(200, input_shape=(window, features), return_sequences=True))
    model4.add(Dropout(0.5))
    model4.add(LSTM(100, input_shape=(window, features), return_sequences=False))
    model4.add(Dropout(0.5))
    model4.add(Dense(1))
    model4.compile(loss='mse', optimizer='adam')

    # test model
    model = Sequential()
    model.add(LSTM(100, input_shape=(window, features), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(50, input_shape=(window, features), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(25, input_shape=(window, features), return_sequences=False))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    
    # from kaggle
    model2 = Sequential()
    model2.add(LSTM(128, return_sequences=True,
               input_shape=(window, features)))
    model2.add(LSTM(64, return_sequences=False))
    model2.add(Dense(25))
    model2.add(Dense(1))
    model2.compile(loss='mse', optimizer='adam', metrics = ['mean_squared_error'])

    return model2

    # return model4


earlystopping = callbacks.EarlyStopping(monitor="val_loss",
                                        mode="min", patience=10,
                                        restore_best_weights=True)

# %%
epochs = [50,100]
batch_sizes = [12, 24]
results = {
    "epoch": [],
    "batch_size": [],
    "score": []
}

for batch_size in batch_sizes:
    for epoch in epochs:
        score_tracking = []
        for train_index, val_index in tscv.split(train):
            model = model_lstm(5, 1)

            train_data, val_data = train[:max(train_index)], train[max(train_index):]

            train_data_x, train_data_y = reconstruct_data(train_data, 5)
            val_data_x, val_data_y = reconstruct_data(val_data, 5)
            #print(train_data_x.shape, train_data_y.shape)

            train_data_x = np.reshape(
                train_data_x, (train_data_x.shape[0], train_data_x.shape[1], 1))
            val_data_x = np.reshape(
                val_data_x, (val_data_x.shape[0], val_data_x.shape[1], 1))

            model.fit(train_data_x, train_data_y, epochs=epoch, batch_size=batch_size,
                        validation_data=(val_data_x, val_data_y),
                        verbose=0, callbacks=[], shuffle=False)
            
            test_loss = model.evaluate(test_x, test_y)
            score_tracking.append(test_loss)
            
        Mean_Squared_Error = np.mean(score_tracking)
        results["epoch"].append(epoch)
        results["batch_size"].append(batch_size)
        results["score"].append(Mean_Squared_Error)
        #Append to dataframe
        #params = pd.concat([params, pd.DataFrame({'batch_size': batch_size, 'epoch': epoch, 'score': Mean_Squared_Error})],
        #                   axis=0)


# Get Best Params individual
params = pd.DataFrame(results).sort_values(by=['score'], ascending=True, inplace=True, ignore_index=True)
params.head(10)
# Out:
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0273 - mean_squared_error: 0.0273
# 68/68 [==============================] - 0s 4ms/step - loss: 0.2313 - mean_squared_error: 0.2313
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1403 - mean_squared_error: 0.1403
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2321 - mean_squared_error: 0.2321
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1504 - mean_squared_error: 0.1504
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1362 - mean_squared_error: 0.1362
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1111 - mean_squared_error: 0.1111
# 68/68 [==============================] - 0s 2ms/step - loss: 0.1842 - mean_squared_error: 0.1842
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0778 - mean_squared_error: 0.0778
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0525 - mean_squared_error: 0.0525
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0620 - mean_squared_error: 0.0620
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0530 - mean_squared_error: 0.0530
# 68/68 [==============================] - 0s 2ms/step - loss: 0.1546 - mean_squared_error: 0.1546
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0366 - mean_squared_error: 0.0366
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1246 - mean_squared_error: 0.1246
# 68/68 [==============================] - 0s 2ms/step - loss: 0.1552 - mean_squared_error: 0.1552
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0859 - mean_squared_error: 0.0859
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1314 - mean_squared_error: 0.1314
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0190 - mean_squared_error: 0.0190
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0937 - mean_squared_error: 0.0937
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 44
#      37         #Append to dataframe
#      38         #params = pd.concat([params, pd.DataFrame({'batch_size': batch_size, 'epoch': epoch, 'score': Mean_Squared_Error})],
#      39         #                   axis=0)
#      40
#      41
#      42 # Get Best Params individual
#      43 params = pd.DataFrame(results).sort_values(by=['score'], ascending=True, inplace=True, ignore_index=True)
# ---> 44 params.head(10)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
#Constructing final model using best params
model = model_lstm(5, 1)
train_x = np.reshape(train_x, (train_x.shape[0],  train_x.shape[1], 1))
test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))

history = model.fit(
    train_x, train_y, epochs=int(params.iloc[0, 1]), batch_size=int(params.iloc[0, 0]), verbose=2)

y_predicted = model.predict(train_x)



# unscaled_predicted = scaler.inverse_transform(y_predicted)

plt.figure(figsize=(30, 10))
plt.plot(train_y, label="actual")
plt.plot(y_predicted, label="prediction")
plt.legend(fontsize=20)
plt.grid(axis="both")
plt.title("Actual close price and pedicted one on train set", fontsize=25)
plt.show()
# Out:
# Epoch 1/100
# 212/212 - 6s - loss: 8.5876e-04 - mean_squared_error: 8.5876e-04 - 6s/epoch - 30ms/step
# Epoch 2/100
# 212/212 - 2s - loss: 2.5818e-05 - mean_squared_error: 2.5818e-05 - 2s/epoch - 8ms/step
# Epoch 3/100
# 212/212 - 2s - loss: 2.6706e-05 - mean_squared_error: 2.6706e-05 - 2s/epoch - 8ms/step
# Epoch 4/100
# 212/212 - 2s - loss: 2.7735e-05 - mean_squared_error: 2.7735e-05 - 2s/epoch - 9ms/step
# Epoch 5/100
# 212/212 - 2s - loss: 2.5573e-05 - mean_squared_error: 2.5573e-05 - 2s/epoch - 9ms/step
# Epoch 6/100
# 212/212 - 2s - loss: 2.5099e-05 - mean_squared_error: 2.5099e-05 - 2s/epoch - 9ms/step
# Epoch 7/100
# 212/212 - 2s - loss: 2.5171e-05 - mean_squared_error: 2.5171e-05 - 2s/epoch - 10ms/step
# Epoch 8/100
# 212/212 - 2s - loss: 2.9818e-05 - mean_squared_error: 2.9818e-05 - 2s/epoch - 9ms/step
# Epoch 9/100
# 212/212 - 2s - loss: 2.6810e-05 - mean_squared_error: 2.6810e-05 - 2s/epoch - 9ms/step
# Epoch 10/100
# 212/212 - 2s - loss: 2.9967e-05 - mean_squared_error: 2.9967e-05 - 2s/epoch - 9ms/step
# Epoch 11/100
# 212/212 - 2s - loss: 2.5167e-05 - mean_squared_error: 2.5167e-05 - 2s/epoch - 8ms/step
# Epoch 12/100
# 212/212 - 2s - loss: 2.5352e-05 - mean_squared_error: 2.5352e-05 - 2s/epoch - 8ms/step
# Epoch 13/100
# 212/212 - 2s - loss: 2.6569e-05 - mean_squared_error: 2.6569e-05 - 2s/epoch - 8ms/step
# Epoch 14/100
# 212/212 - 2s - loss: 2.4400e-05 - mean_squared_error: 2.4400e-05 - 2s/epoch - 9ms/step
# Epoch 15/100
# 212/212 - 2s - loss: 2.4211e-05 - mean_squared_error: 2.4211e-05 - 2s/epoch - 9ms/step
# Epoch 16/100
# 212/212 - 2s - loss: 2.5234e-05 - mean_squared_error: 2.5234e-05 - 2s/epoch - 9ms/step
# Epoch 17/100
# 212/212 - 2s - loss: 2.1884e-05 - mean_squared_error: 2.1884e-05 - 2s/epoch - 9ms/step
# Epoch 18/100
# 212/212 - 2s - loss: 2.0535e-05 - mean_squared_error: 2.0535e-05 - 2s/epoch - 8ms/step
# Epoch 19/100
# 212/212 - 2s - loss: 1.6746e-05 - mean_squared_error: 1.6746e-05 - 2s/epoch - 9ms/step
# Epoch 20/100
# 212/212 - 2s - loss: 1.7566e-05 - mean_squared_error: 1.7566e-05 - 2s/epoch - 9ms/step
# Epoch 21/100
# 212/212 - 2s - loss: 2.0281e-05 - mean_squared_error: 2.0281e-05 - 2s/epoch - 8ms/step
# Epoch 22/100
# 212/212 - 2s - loss: 1.6316e-05 - mean_squared_error: 1.6316e-05 - 2s/epoch - 9ms/step
# Epoch 23/100
# 212/212 - 2s - loss: 1.5743e-05 - mean_squared_error: 1.5743e-05 - 2s/epoch - 8ms/step
# Epoch 24/100
# 212/212 - 2s - loss: 1.5856e-05 - mean_squared_error: 1.5856e-05 - 2s/epoch - 8ms/step
# Epoch 25/100
# 212/212 - 2s - loss: 1.4499e-05 - mean_squared_error: 1.4499e-05 - 2s/epoch - 8ms/step
# Epoch 26/100
# 212/212 - 2s - loss: 1.4072e-05 - mean_squared_error: 1.4072e-05 - 2s/epoch - 8ms/step
# Epoch 27/100
# 212/212 - 2s - loss: 1.6813e-05 - mean_squared_error: 1.6813e-05 - 2s/epoch - 8ms/step
# Epoch 28/100
# 212/212 - 2s - loss: 1.4142e-05 - mean_squared_error: 1.4142e-05 - 2s/epoch - 8ms/step
# Epoch 29/100
# 212/212 - 2s - loss: 1.4637e-05 - mean_squared_error: 1.4637e-05 - 2s/epoch - 8ms/step
# Epoch 30/100
# 212/212 - 2s - loss: 1.5462e-05 - mean_squared_error: 1.5462e-05 - 2s/epoch - 9ms/step
# Epoch 31/100
# 212/212 - 2s - loss: 1.2329e-05 - mean_squared_error: 1.2329e-05 - 2s/epoch - 9ms/step
# Epoch 32/100
# 212/212 - 2s - loss: 1.4802e-05 - mean_squared_error: 1.4802e-05 - 2s/epoch - 9ms/step
# Epoch 33/100
# 212/212 - 2s - loss: 1.4788e-05 - mean_squared_error: 1.4788e-05 - 2s/epoch - 9ms/step
# Epoch 34/100
# 212/212 - 2s - loss: 1.4464e-05 - mean_squared_error: 1.4464e-05 - 2s/epoch - 9ms/step
# Epoch 35/100
# 212/212 - 2s - loss: 1.5770e-05 - mean_squared_error: 1.5770e-05 - 2s/epoch - 9ms/step
# Epoch 36/100
# 212/212 - 2s - loss: 1.6936e-05 - mean_squared_error: 1.6936e-05 - 2s/epoch - 9ms/step
# Epoch 37/100
# 212/212 - 2s - loss: 1.3403e-05 - mean_squared_error: 1.3403e-05 - 2s/epoch - 9ms/step
# Epoch 38/100
# 212/212 - 2s - loss: 1.2491e-05 - mean_squared_error: 1.2491e-05 - 2s/epoch - 9ms/step
# Epoch 39/100
# 212/212 - 2s - loss: 1.2507e-05 - mean_squared_error: 1.2507e-05 - 2s/epoch - 10ms/step
# Epoch 40/100
# 212/212 - 2s - loss: 1.3128e-05 - mean_squared_error: 1.3128e-05 - 2s/epoch - 10ms/step
# Epoch 41/100
# 212/212 - 2s - loss: 1.3470e-05 - mean_squared_error: 1.3470e-05 - 2s/epoch - 10ms/step
# Epoch 42/100
# 212/212 - 2s - loss: 1.2441e-05 - mean_squared_error: 1.2441e-05 - 2s/epoch - 10ms/step
# Epoch 43/100
# 212/212 - 2s - loss: 1.4177e-05 - mean_squared_error: 1.4177e-05 - 2s/epoch - 10ms/step
# Epoch 44/100
# 212/212 - 2s - loss: 1.2912e-05 - mean_squared_error: 1.2912e-05 - 2s/epoch - 10ms/step
# Epoch 45/100
# 212/212 - 2s - loss: 1.6305e-05 - mean_squared_error: 1.6305e-05 - 2s/epoch - 10ms/step
# Epoch 46/100
# 212/212 - 3s - loss: 1.3501e-05 - mean_squared_error: 1.3501e-05 - 3s/epoch - 13ms/step
# Epoch 47/100
# 212/212 - 2s - loss: 1.3554e-05 - mean_squared_error: 1.3554e-05 - 2s/epoch - 8ms/step
# Epoch 48/100
# 212/212 - 2s - loss: 1.3752e-05 - mean_squared_error: 1.3752e-05 - 2s/epoch - 7ms/step
# Epoch 49/100
# 212/212 - 1s - loss: 1.3860e-05 - mean_squared_error: 1.3860e-05 - 1s/epoch - 6ms/step
# Epoch 50/100
# 212/212 - 1s - loss: 1.2677e-05 - mean_squared_error: 1.2677e-05 - 1s/epoch - 6ms/step
# Epoch 51/100
# 212/212 - 1s - loss: 1.4230e-05 - mean_squared_error: 1.4230e-05 - 1s/epoch - 7ms/step
# Epoch 52/100
# 212/212 - 2s - loss: 1.2767e-05 - mean_squared_error: 1.2767e-05 - 2s/epoch - 7ms/step
# Epoch 53/100
# 212/212 - 2s - loss: 1.3753e-05 - mean_squared_error: 1.3753e-05 - 2s/epoch - 8ms/step
# Epoch 54/100
# 212/212 - 1s - loss: 1.4638e-05 - mean_squared_error: 1.4638e-05 - 1s/epoch - 7ms/step
# Epoch 55/100
# 212/212 - 1s - loss: 1.2717e-05 - mean_squared_error: 1.2717e-05 - 1s/epoch - 7ms/step
# Epoch 56/100
# 212/212 - 2s - loss: 1.3898e-05 - mean_squared_error: 1.3898e-05 - 2s/epoch - 8ms/step
# Epoch 57/100
# 212/212 - 2s - loss: 1.3352e-05 - mean_squared_error: 1.3352e-05 - 2s/epoch - 7ms/step
# Epoch 58/100
# 212/212 - 1s - loss: 1.5505e-05 - mean_squared_error: 1.5505e-05 - 1s/epoch - 7ms/step
# Epoch 59/100
# 212/212 - 1s - loss: 1.2469e-05 - mean_squared_error: 1.2469e-05 - 1s/epoch - 7ms/step
# Epoch 60/100
# 212/212 - 1s - loss: 1.3280e-05 - mean_squared_error: 1.3280e-05 - 1s/epoch - 7ms/step
# Epoch 61/100
# 212/212 - 2s - loss: 1.4643e-05 - mean_squared_error: 1.4643e-05 - 2s/epoch - 7ms/step
# Epoch 62/100
# 212/212 - 1s - loss: 1.3292e-05 - mean_squared_error: 1.3292e-05 - 1s/epoch - 7ms/step
# Epoch 63/100
# 212/212 - 1s - loss: 1.3864e-05 - mean_squared_error: 1.3864e-05 - 1s/epoch - 7ms/step
# Epoch 64/100
# 212/212 - 1s - loss: 1.2463e-05 - mean_squared_error: 1.2463e-05 - 1s/epoch - 7ms/step
# Epoch 65/100
# 212/212 - 1s - loss: 1.3630e-05 - mean_squared_error: 1.3630e-05 - 1s/epoch - 6ms/step
# Epoch 66/100
# 212/212 - 1s - loss: 1.5098e-05 - mean_squared_error: 1.5098e-05 - 1s/epoch - 7ms/step
# Epoch 67/100
# 212/212 - 1s - loss: 1.2793e-05 - mean_squared_error: 1.2793e-05 - 1s/epoch - 7ms/step
# Epoch 68/100
# 212/212 - 1s - loss: 1.2434e-05 - mean_squared_error: 1.2434e-05 - 1s/epoch - 7ms/step
# Epoch 69/100
# 212/212 - 1s - loss: 1.3982e-05 - mean_squared_error: 1.3982e-05 - 1s/epoch - 6ms/step
# Epoch 70/100
# 212/212 - 1s - loss: 1.3787e-05 - mean_squared_error: 1.3787e-05 - 1s/epoch - 6ms/step
# Epoch 71/100
# 212/212 - 1s - loss: 1.3985e-05 - mean_squared_error: 1.3985e-05 - 1s/epoch - 6ms/step
# Epoch 72/100
# 212/212 - 1s - loss: 1.3436e-05 - mean_squared_error: 1.3436e-05 - 1s/epoch - 7ms/step
# Epoch 73/100
# 212/212 - 2s - loss: 1.4015e-05 - mean_squared_error: 1.4015e-05 - 2s/epoch - 7ms/step
# Epoch 74/100
# 212/212 - 2s - loss: 1.2448e-05 - mean_squared_error: 1.2448e-05 - 2s/epoch - 7ms/step
# Epoch 75/100
# 212/212 - 2s - loss: 1.2202e-05 - mean_squared_error: 1.2202e-05 - 2s/epoch - 8ms/step
# Epoch 76/100
# 212/212 - 1s - loss: 1.1817e-05 - mean_squared_error: 1.1817e-05 - 1s/epoch - 6ms/step
# Epoch 77/100
# 212/212 - 1s - loss: 1.3930e-05 - mean_squared_error: 1.3930e-05 - 1s/epoch - 6ms/step
# Epoch 78/100
# 212/212 - 1s - loss: 1.2727e-05 - mean_squared_error: 1.2727e-05 - 1s/epoch - 6ms/step
# Epoch 79/100
# 212/212 - 1s - loss: 1.3151e-05 - mean_squared_error: 1.3151e-05 - 1s/epoch - 6ms/step
# Epoch 80/100
# 212/212 - 1s - loss: 1.3280e-05 - mean_squared_error: 1.3280e-05 - 1s/epoch - 6ms/step
# Epoch 81/100
# 212/212 - 1s - loss: 1.2670e-05 - mean_squared_error: 1.2670e-05 - 1s/epoch - 6ms/step
# Epoch 82/100
# 212/212 - 1s - loss: 1.2758e-05 - mean_squared_error: 1.2758e-05 - 1s/epoch - 6ms/step
# Epoch 83/100
# 212/212 - 1s - loss: 1.3951e-05 - mean_squared_error: 1.3951e-05 - 1s/epoch - 6ms/step
# Epoch 84/100
# 212/212 - 1s - loss: 1.3701e-05 - mean_squared_error: 1.3701e-05 - 1s/epoch - 6ms/step
# Epoch 85/100
# 212/212 - 1s - loss: 1.2395e-05 - mean_squared_error: 1.2395e-05 - 1s/epoch - 6ms/step
# Epoch 86/100
# 212/212 - 1s - loss: 1.3556e-05 - mean_squared_error: 1.3556e-05 - 1s/epoch - 6ms/step
# Epoch 87/100
# 212/212 - 1s - loss: 1.3043e-05 - mean_squared_error: 1.3043e-05 - 1s/epoch - 7ms/step
# Epoch 88/100
# 212/212 - 1s - loss: 1.3336e-05 - mean_squared_error: 1.3336e-05 - 1s/epoch - 6ms/step
# Epoch 89/100
# 212/212 - 1s - loss: 1.3290e-05 - mean_squared_error: 1.3290e-05 - 1s/epoch - 6ms/step
# Epoch 90/100
# 212/212 - 1s - loss: 1.2182e-05 - mean_squared_error: 1.2182e-05 - 1s/epoch - 7ms/step
# Epoch 91/100
# 212/212 - 1s - loss: 1.2425e-05 - mean_squared_error: 1.2425e-05 - 1s/epoch - 6ms/step
# Epoch 92/100
# 212/212 - 1s - loss: 1.2699e-05 - mean_squared_error: 1.2699e-05 - 1s/epoch - 6ms/step
# Epoch 93/100
# 212/212 - 1s - loss: 1.2135e-05 - mean_squared_error: 1.2135e-05 - 1s/epoch - 6ms/step
# Epoch 94/100
# 212/212 - 1s - loss: 1.2469e-05 - mean_squared_error: 1.2469e-05 - 1s/epoch - 6ms/step
# Epoch 95/100
# 212/212 - 1s - loss: 1.2352e-05 - mean_squared_error: 1.2352e-05 - 1s/epoch - 6ms/step
# Epoch 96/100
# 212/212 - 1s - loss: 1.3008e-05 - mean_squared_error: 1.3008e-05 - 1s/epoch - 6ms/step
# Epoch 97/100
# 212/212 - 1s - loss: 1.2570e-05 - mean_squared_error: 1.2570e-05 - 1s/epoch - 7ms/step
# Epoch 98/100
# 212/212 - 1s - loss: 1.2733e-05 - mean_squared_error: 1.2733e-05 - 1s/epoch - 7ms/step
# Epoch 99/100
# 212/212 - 1s - loss: 1.3019e-05 - mean_squared_error: 1.3019e-05 - 1s/epoch - 7ms/step
# Epoch 100/100
# 212/212 - 1s - loss: 1.4248e-05 - mean_squared_error: 1.4248e-05 - 1s/epoch - 6ms/step
# 159/159 [==============================] - 1s 3ms/step

# %%
# Predicting Testing Dataset
test_predict = model.predict(test_x)
print(test_x.shape)
#print(test_predict)
# test_predict = scaler.inverse_transform(test_predict)
# test_labels = scaler.inverse_transform(test_y)

plt.figure(figsize=(30, 10))
plt.plot(test_y, label="actual")
plt.plot(test_predict, label="prediction")
plt.legend(fontsize=20)
plt.grid(axis="both")
plt.title("Actual close price and pedicted one on test set", fontsize=25)
plt.show()
# Out:
# 68/68 [==============================] - 0s 3ms/step
# (2173, 5, 1)

# %%
predictions = scaler.inverse_transform(test_predict)
print(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - test) ** 2)))
rmse
# Out:
# [[184.1342 ]
#  [185.28085]
#  [186.94052]
#  ...
#  [390.74857]
#  [390.60803]
#  [384.99292]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 5
#       2 print(predictions)
#       4 # Get the root mean squared error (RMSE)
# ----> 5 rmse = np.sqrt(np.mean(((predictions - test) ** 2)))
#       6 rmse
#
# ValueError: operands could not be broadcast together with shapes (2173,1) (2179,1)

# %%
# Plot the data
train = data[:int(
    len(dataset) * 0.7)]
valid = data[int(
    len(dataset) * 0.7):]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16, 6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 6
#       2 train = data[:int(
#       3     len(dataset) * 0.7)]
#       4 valid = data[int(
#       5     len(dataset) * 0.7):]
# ----> 6 valid['Predictions'] = predictions
#       7 # Visualize the data
#       8 plt.figure(figsize=(16, 6))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (2173) does not match length of index (2179)
